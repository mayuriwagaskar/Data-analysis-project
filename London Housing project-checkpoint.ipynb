# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\MAYURI\Downloads\housing_in_london_monthly_variables.csv')

# %%
df
# Out:
#              date            area  average_price       code  houses_sold  \
# 0      1995-01-01  city of london          91449  E09000001         17.0
# 1      1995-02-01  city of london          82203  E09000001          7.0
# 2      1995-03-01  city of london          79121  E09000001         14.0
# 3      1995-04-01  city of london          77101  E09000001          7.0
# 4      1995-05-01  city of london          84409  E09000001         10.0
# ...           ...             ...            ...        ...          ...
# 13544  2019-09-01         england         249942  E92000001      64605.0
# 13545  2019-10-01         england         249376  E92000001      68677.0
# 13546  2019-11-01         england         248515  E92000001      67814.0
# 13547  2019-12-01         england         250410  E92000001          NaN
# 13548  2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  borough_flag
# 0               NaN             1
# ...

# %%
df.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# borough_flag     13549
# dtype: int64

# %%
df.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# borough_flag        0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# borough_flag        0
# dtype: int64

# %%
df.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# borough_flag       int64
# dtype: object

# %% [markdown]
# # (A) Convert the Data column to Data-Time format?

# %%
df.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# borough_flag       int64
# dtype: object

# %%
df.date=pd.to_datetime(df.date)
# Out:
# C:\Users\MAYURI\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# borough_flag              int64
# dtype: object

# %% [markdown]
# # (B) Add a new column "year" in the dataframe which contains years only

# %%
df['year']=df.date.dt.year
# Out:
# <ipython-input-37-edf06567b97b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year']=df.date.dt.year

# %%
df
# Out:
#             date            area                 average_price       code  \
# 0     1995-01-01  city of london 1970-01-01 00:00:00.000091449  E09000001
# 1     1995-02-01  city of london 1970-01-01 00:00:00.000082203  E09000001
# 2     1995-03-01  city of london 1970-01-01 00:00:00.000079121  E09000001
# 3     1995-04-01  city of london 1970-01-01 00:00:00.000077101  E09000001
# 4     1995-05-01  city of london 1970-01-01 00:00:00.000084409  E09000001
# ...          ...             ...                           ...        ...
# 13544 2019-09-01         england 1970-01-01 00:00:00.000249942  E92000001
# 13545 2019-10-01         england 1970-01-01 00:00:00.000249376  E92000001
# 13546 2019-11-01         england 1970-01-01 00:00:00.000248515  E92000001
# 13547 2019-12-01         england 1970-01-01 00:00:00.000250410  E92000001
# 13548 2020-01-01         england 1970-01-01 00:00:00.000247355  E92000001
#
#        houses_sold  no_of_crimes  borough_flag  year
# ...

# %% [markdown]
# # (B.1)Add a new column "month" in the dataframe at second position which contains month only?

# %%
df.insert(1,'month',df.date.dt.month)

# %%
df
# Out:
#             date  month            area                 average_price  \
# 0     1995-01-01      1  city of london 1970-01-01 00:00:00.000091449
# 1     1995-02-01      2  city of london 1970-01-01 00:00:00.000082203
# 2     1995-03-01      3  city of london 1970-01-01 00:00:00.000079121
# 3     1995-04-01      4  city of london 1970-01-01 00:00:00.000077101
# 4     1995-05-01      5  city of london 1970-01-01 00:00:00.000084409
# ...          ...    ...             ...                           ...
# 13544 2019-09-01      9         england 1970-01-01 00:00:00.000249942
# 13545 2019-10-01     10         england 1970-01-01 00:00:00.000249376
# 13546 2019-11-01     11         england 1970-01-01 00:00:00.000248515
# 13547 2019-12-01     12         england 1970-01-01 00:00:00.000250410
# 13548 2020-01-01      1         england 1970-01-01 00:00:00.000247355
#
#             code  houses_sold  no_of_crimes  borough_flag  year
# ...

# %% [markdown]
# # (c) Remove the columns 'year' and 'month'from the dataframe

# %%
df.drop(['year','month'], axis = 1,inplace=True)

# %%
df
# Out:
#             date            area                 average_price       code  \
# 0     1995-01-01  city of london 1970-01-01 00:00:00.000091449  E09000001
# 1     1995-02-01  city of london 1970-01-01 00:00:00.000082203  E09000001
# 2     1995-03-01  city of london 1970-01-01 00:00:00.000079121  E09000001
# 3     1995-04-01  city of london 1970-01-01 00:00:00.000077101  E09000001
# 4     1995-05-01  city of london 1970-01-01 00:00:00.000084409  E09000001
# ...          ...             ...                           ...        ...
# 13544 2019-09-01         england 1970-01-01 00:00:00.000249942  E92000001
# 13545 2019-10-01         england 1970-01-01 00:00:00.000249376  E92000001
# 13546 2019-11-01         england 1970-01-01 00:00:00.000248515  E92000001
# 13547 2019-12-01         england 1970-01-01 00:00:00.000250410  E92000001
# 13548 2020-01-01         england 1970-01-01 00:00:00.000247355  E92000001
#
#        houses_sold  no_of_crimes  borough_flag
# ...

# %% [markdown]
# # (D) Show all the records where 'No.of Crimes'is 0. and How many such records are there?

# %%
df[df.no_of_crimes==0]
# Out:
#           date            area                 average_price       code  \
# 72  2001-01-01  city of london 1970-01-01 00:00:00.000284262  E09000001
# 73  2001-02-01  city of london 1970-01-01 00:00:00.000198137  E09000001
# 74  2001-03-01  city of london 1970-01-01 00:00:00.000189033  E09000001
# 75  2001-04-01  city of london 1970-01-01 00:00:00.000205494  E09000001
# 76  2001-05-01  city of london 1970-01-01 00:00:00.000223459  E09000001
# ..         ...             ...                           ...        ...
# 178 2009-11-01  city of london 1970-01-01 00:00:00.000397909  E09000001
# 179 2009-12-01  city of london 1970-01-01 00:00:00.000411955  E09000001
# 180 2010-01-01  city of london 1970-01-01 00:00:00.000464436  E09000001
# 181 2010-02-01  city of london 1970-01-01 00:00:00.000490525  E09000001
# 182 2010-03-01  city of london 1970-01-01 00:00:00.000498241  E09000001
#
#      houses_sold  no_of_crimes  borough_flag
# 72          24.0           0.0             1
# ...

# %%
len(df[df.no_of_crimes==0])
# Out:
# 104

# %%
df.head()
# Out:
#          date            area  average_price       code  houses_sold  \
# 0  1995-01-01  city of london          91449  E09000001         17.0
# 1  1995-02-01  city of london          82203  E09000001          7.0
# 2  1995-03-01  city of london          79121  E09000001         14.0
# 3  1995-04-01  city of london          77101  E09000001          7.0
# 4  1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  borough_flag
# 0           NaN             1
# 1           NaN             1
# 2           NaN             1
# 3           NaN             1
# 4           NaN             1

# %%
df[df.no_of_crimes==0]
# Out:
#            date            area  average_price       code  houses_sold  \
# 72   2001-01-01  city of london         284262  E09000001         24.0
# 73   2001-02-01  city of london         198137  E09000001         37.0
# 74   2001-03-01  city of london         189033  E09000001         44.0
# 75   2001-04-01  city of london         205494  E09000001         38.0
# 76   2001-05-01  city of london         223459  E09000001         30.0
# ..          ...             ...            ...        ...          ...
# 178  2009-11-01  city of london         397909  E09000001         11.0
# 179  2009-12-01  city of london         411955  E09000001         16.0
# 180  2010-01-01  city of london         464436  E09000001         20.0
# 181  2010-02-01  city of london         490525  E09000001          9.0
# 182  2010-03-01  city of london         498241  E09000001         15.0
#
#      no_of_crimes  borough_flag
# 72            0.0             1
# 73            0.0             1
# ...

# %%
len(df[df.no_of_crimes==0])
# Out:
# 104

# %% [markdown]
# # (E) What is the maximum & minimum "average_price" per year in england?

# %%
df['year']= df.date.dt.year
# Out:
# <ipython-input-38-8b65c8f69cbb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year']= df.date.dt.year

# %%
df.groupby('year').average_price.max()
# Out:
# year
# 1995     53901
# 1996     55755
# 1997     61564
# 1998     65743
# 1999     75071
# 2000     84191
# 2001     95992
# 2002    119982
# 2003    138985
# 2004    160330
# 2005    167244
# 2006    182031
# 2007    194764
# 2008    191750
# 2009    174136
# 2010    180807
# 2011    177335
# 2012    180129
# 2013    188544
# 2014    203639
# 2015    219582
# 2016    231922
# 2017    242628
# 2018    248620
# 2019    250410
# 2020    247355
# Name: average_price, dtype: int64

# %%
df.groupby('year').average_price.min()
# Out:
# year
# 1995     52788
# 1996     52333
# 1997     55789
# 1998     61659
# 1999     65522
# 2000     75219
# 2001     84245
# 2002     96215
# 2003    121610
# 2004    139719
# 2005    158572
# 2006    166544
# 2007    181824
# 2008    165795
# 2009    159340
# 2010    174458
# 2011    173046
# 2012    174161
# 2013    176816
# 2014    188265
# 2015    202856
# 2016    220361
# 2017    231593
# 2018    240428
# 2019    243281
# 2020    247355
# Name: average_price, dtype: int64

# %%
df=df[df.area=='england']

# %%
df
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
# 13249 1995-02-01  england          53096  E92000001      47880.0
# 13250 1995-03-01  england          53201  E92000001      67025.0
# 13251 1995-04-01  england          53591  E92000001      56925.0
# 13252 1995-05-01  england          53678  E92000001      64192.0
# ...          ...      ...            ...        ...          ...
# 13544 2019-09-01  england         249942  E92000001      64605.0
# 13545 2019-10-01  england         249376  E92000001      68677.0
# 13546 2019-11-01  england         248515  E92000001      67814.0
# 13547 2019-12-01  england         250410  E92000001          NaN
# 13548 2020-01-01  england         247355  E92000001          NaN
#
#        no_of_crimes  borough_flag  year
# 13248           NaN             0  1995
# 13249           NaN             0  1995
# 13250           NaN             0  1995
# ...

# %% [markdown]
# # (F) What is max and min no.of crimes record per area?

# %%
df.groupby('area').no_of_crimes.max()
# Out:
# area
# england   NaN
# Name: no_of_crimes, dtype: float64

# %%
df.groupby('area').no_of_crimes.min().sort_values(ascending=True)
# Out:
# area
# england   NaN
# Name: no_of_crimes, dtype: float64

# %% [markdown]
# # (G) Show the total count of records of each area, where average price is less than 100000

# %%
df.head()
# Out:
#              date     area  average_price       code  houses_sold  \
# 13248  1995-01-01  england          53203  E92000001      47639.0
# 13249  1995-02-01  england          53096  E92000001      47880.0
# 13250  1995-03-01  england          53201  E92000001      67025.0
# 13251  1995-04-01  england          53591  E92000001      56925.0
# 13252  1995-05-01  england          53678  E92000001      64192.0
#
#        no_of_crimes  borough_flag
# 13248           NaN             0
# 13249           NaN             0
# 13250           NaN             0
# 13251           NaN             0
# 13252           NaN             0

# %%
df[df.average_price <100000].area.value_counts()
# Out:
# england    87
# Name: area, dtype: int64

# %%
df[df.average_price <100000]
# Out:
#              date     area  average_price       code  houses_sold  \
# 13248  1995-01-01  england          53203  E92000001      47639.0
# 13249  1995-02-01  england          53096  E92000001      47880.0
# 13250  1995-03-01  england          53201  E92000001      67025.0
# 13251  1995-04-01  england          53591  E92000001      56925.0
# 13252  1995-05-01  england          53678  E92000001      64192.0
# ...           ...      ...            ...        ...          ...
# 13330  2001-11-01  england          95083  E92000001     109149.0
# 13331  2001-12-01  england          95992  E92000001      93329.0
# 13332  2002-01-01  england          96215  E92000001      71678.0
# 13333  2002-02-01  england          96676  E92000001      77131.0
# 13334  2002-03-01  england          98962  E92000001     102828.0
#
#        no_of_crimes  borough_flag
# 13248           NaN             0
# 13249           NaN             0
# 13250           NaN             0
# ...
